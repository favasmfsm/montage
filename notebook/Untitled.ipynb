# %%
import pandas as pd

# %%
df = pd.read_csv("dealer.csv")

# %%
df
# Out:
#       Unnamed: 0                              Name                      Phone  \
# 0              0                    Hillside Honda  888-732-8104 866-608-6740
# 1              1                   Hillside Toyota               718-657-5500
# 2              2  Ford Lincoln Of Queens Boulevard                        NaN
# 3              3                  Life Quality Bmw  866-340-5487 877-222-9413
# 4              4                   Bay Ridge Mazda                        NaN
# ...          ...                               ...                        ...
# 2888        2888                     Madison Honda               973-381-1344
# 2889        2889                White Plains Honda               914-256-8646
# 2890        2890                   Bmw Of Freehold               732-298-9055
# 2891        2891                 Millennium Toyota               516-336-3050
# 2892        2892              Toyota Of Massapequa             (516) 217-1517
#
# ...

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                                   Name                      Phone  Status  \
# 0                       Hillside Honda  888-732-8104 866-608-6740  active
# 1                      Hillside Toyota               718-657-5500  active
# 2     Ford Lincoln Of Queens Boulevard                        NaN  active
# 3                     Life Quality Bmw  866-340-5487 877-222-9413  active
# 4                      Bay Ridge Mazda                        NaN  active
# ...                                ...                        ...     ...
# 1448                     Madison Honda               973-381-1344  active
# 1449                White Plains Honda               914-256-8646  active
# 1450                   Bmw Of Freehold               732-298-9055  active
# 1451                 Millennium Toyota               516-336-3050  active
# 1452              Toyota Of Massapequa             (516) 217-1517  active
#
#            Type                           Street          City State    Zip
# ...

# %%
df.to_csv("my_dealers_data.csv",index=False)

# %%
df.head(50)
# Out:
#                                           Name                         Phone  \
# 0                               Hillside Honda     888-732-8104 866-608-6740
# 1                              Hillside Toyota                  718-657-5500
# 2             Ford Lincoln Of Queens Boulevard                           NaN
# 3                             Life Quality Bmw     866-340-5487 877-222-9413
# 4                              Bay Ridge Mazda                           NaN
# 5                         Bay Ridge Volkswagen                (718) 351-7000
# 6                            Lexus Of Brooklyn                (866) 810-6909
# 7                              Bay Ridge Honda                  718-836-4600
# 8                             Bay Ridge Nissan     877-729-2197 888-668-9537
# 9    Chrysler Dodge Jeep Ram Fiat Of Bay Ridge                (866) 238-4105
# 80        Kings County Chrysler Dodge Jeep Ram                (888) 865-7161
# ...

# %%
df1 = df[['Name']].drop_duplicates()

# %%
df1.to_csv("../output/prefered_dealer_names.csv",index=False)
